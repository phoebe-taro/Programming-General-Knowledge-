# %%
scores = [70, 60, 74, 56, 50, 80, 90, 70, 60, 100]
a = []
sum = 0
for i in scores:
  sum += i
  if i < 60:
    a.append(i)
print('小於60的數有 :',*a)
print('此串列的平均分數是：',sum/len(scores))
# Out:
# 小於60的數有 : 56 50
# 此串列的平均分數是： 71.0
