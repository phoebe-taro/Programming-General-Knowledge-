# %%
h = int(input('請輸入您的身高:'))
w = int(input('請輸入您的體重:'))
bmi = w/(h/100)**2
print(f'您的BMI為:{bmi:.2f}')
if bmi < 18.5:
    print('體重過輕')
elif 18.5 <= bmi < 24:
    print('體重正常')
elif 24 <= bmi < 27:
    print('體重過重')
else:
    print('體重肥胖')
# Out:
# 請輸入您的身高:165
# 請輸入您的體重:80
# 您的BMI為:29.38
# 體重肥胖
